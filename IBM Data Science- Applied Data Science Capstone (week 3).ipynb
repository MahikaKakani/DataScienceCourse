# %% [markdown]
# # Visual Analytics with Folium

# %%
# !pip install wget

import os
import pandas as pd
try:
    import folium
    import wget
except ImportError as e:
    # !{sys.executable} -m pip install folium wget
    import folium
    import wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=1cfc81ebdb272af2f977838752ddebd5cab0b7ebdbcef1f2529a83d6ea0d6648
#   Stored in directory: c:\users\mahika\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
spacex_df=pd.read_csv("spacex_launch_geo.csv")
spacex_df
# Out:
#     Flight Number        Date Time (UTC) Booster Version   Launch Site  \
# 0               1  04-06-2010   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1               2  08-12-2010   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2               3  22-05-2012   07:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3               4  08-10-2012   00:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4               5  01-03-2013   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# 5               7  03-12-2013   22:41:00         F9 v1.1   CCAFS LC-40
# 6               8  06-01-2014   22:06:00         F9 v1.1   CCAFS LC-40
# 7               9  18-04-2014   19:25:00         F9 v1.1   CCAFS LC-40
# 8              10  14-07-2014   15:15:00         F9 v1.1   CCAFS LC-40
# 9              11  05-08-2014   08:00:00         F9 v1.1   CCAFS LC-40
# 10             12  07-09-2014   05:00:00   F9 v1.1 B1011   CCAFS LC-40
# 11             13  21-09-2014   05:52:00   F9 v1.1 B1010   CCAFS LC-40
# 12             14  10-01-2015   09:47:00   F9 v1.1 B1012   CCAFS LC-40
# 13             15  11-02-2015   23:03:00   F9 v1.1 B1013   CCAFS LC-40
# 14             16  02-03-2015   03:50:00   F9 v1.1 B1014   CCAFS LC-40
# 15             17  14-04-2015   20:10:00   F9 v1.1 B1015   CCAFS LC-40
# 16             18  27-04-2015   23:03:00   F9 v1.1 B1016   CCAFS LC-40
# 17             19  28-06-2015   14:21:00   F9 v1.1 B1018   CCAFS LC-40
# 18             20  22-12-2015   01:29:00     F9 FT B1019   CCAFS LC-40
# 19             22  04-03-2016   23:35:00     F9 FT B1020   CCAFS LC-40
# 20             23  08-04-2016   20:43:00   F9 FT B1021.1   CCAFS LC-40
# 21             24  06-05-2016   05:21:00     F9 FT B1022   CCAFS LC-40
# 22             25  27-05-2016   21:39:00   F9 FT B1023.1   CCAFS LC-40
# 23             26  15-06-2016   14:29:00     F9 FT B1024   CCAFS LC-40
# 24             27  18-07-2016   04:45:00   F9 FT B1025.1   CCAFS LC-40
# 25             28  14-08-2016   05:26:00     F9 FT B1026   CCAFS LC-40
# 26              6  29-09-2013   16:00:00  F9 v1.1  B1003   VAFB SLC-4E
# 27             21  17-01-2016   18:42:00   F9 v1.1 B1017   VAFB SLC-4E
# 28             29  14-01-2017   17:54:00   F9 FT B1029.1   VAFB SLC-4E
# 29             37  25-06-2017   20:25:00   F9 FT B1036.1   VAFB SLC-4E
# 30             40  24-08-2017   18:51:00   F9 FT B1038.1   VAFB SLC-4E
# 31             42  09-10-2017   12:37:00   F9 B4 B1041.1   VAFB SLC-4E
# 32             46  23-12-2017   01:27:00  F9 FT  B1036.2   VAFB SLC-4E
# 33             49  22-02-2018   14:17:00  F9 FT  B1038.2   VAFB SLC-4E
# 34             51  30-03-2018   14:14:00  F9 B4  B1041.2   VAFB SLC-4E
# 35             55  22-05-2018   19:47:58  F9 B4  B1043.2   VAFB SLC-4E
# 36             30  19-02-2017   14:39:00   F9 FT B1031.1    KSC LC-39A
# 37             31  16-03-2017   06:00:00     F9 FT B1030    KSC LC-39A
# 38             32  30-03-2017   22:27:00  F9 FT  B1021.2    KSC LC-39A
# 39             33  01-05-2017   11:15:00   F9 FT B1032.1    KSC LC-39A
# 40             34  15-05-2017   23:21:00     F9 FT B1034    KSC LC-39A
# 41             35  03-06-2017   21:07:00   F9 FT B1035.1    KSC LC-39A
# 42             36  23-06-2017   19:10:00  F9 FT  B1029.2    KSC LC-39A
# 43             38  05-07-2017   23:38:00     F9 FT B1037    KSC LC-39A
# 44             39  14-08-2017   16:31:00   F9 B4 B1039.1    KSC LC-39A
# 45             41  07-09-2017   14:00:00   F9 B4 B1040.1    KSC LC-39A
# 46             43  11-10-2017   22:53:00  F9 FT  B1031.2    KSC LC-39A
# 47             44  30-10-2017   19:34:00   F9 B4 B1042.1    KSC LC-39A
# 48             54  11-05-2018   20:14:00  F9 B5  B1046.1    KSC LC-39A
# 49             45  15-12-2017   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 50             47  08-01-2018   01:00:00   F9 B4 B1043.1  CCAFS SLC-40
# 51             48  31-01-2018   21:25:00  F9 FT  B1032.2  CCAFS SLC-40
# 52             50  06-03-2018   05:33:00     F9 B4 B1044  CCAFS SLC-40
# 53             52  02-04-2018   20:30:00  F9 B4  B1039.2  CCAFS SLC-40
# 54             53  18-04-2018   22:51:00   F9 B4 B1045.1  CCAFS SLC-40
# 55             56  04-06-2018   04:45:00  F9 B4  B1040.2  CCAFS SLC-40
#
#                                               Payload  Payload Mass (kg)  \
# 0                Dragon Spacecraft Qualification Unit               0.00
# 1   Dragon demo flight C1, two CubeSats,  barrel o...               0.00
# 2                              Dragon demo flight C2+             525.00
# 3                                        SpaceX CRS-1             500.00
# 4                                        SpaceX CRS-2             677.00
# 5                                               SES-8            3170.00
# 6                                           Thaicom 6            3325.00
# 7                                        SpaceX CRS-3            2296.00
# 8             OG2 Mission 1  6 Orbcomm-OG2 satellites            1316.00
# 9                                           AsiaSat 8            4535.00
# 10                                          AsiaSat 6            4428.00
# 11                                       SpaceX CRS-4            2216.00
# 12                                       SpaceX CRS-5            2395.00
# 13                                             DSCOVR             570.00
# 14                         ABS-3A Eutelsat 115 West B            4159.00
# 15                                       SpaceX CRS-6            1898.00
# 16                       TürkmenÄlem 52°E / MonacoSAT            4707.00
# 17                                       SpaceX CRS-7            1952.00
# 18          OG2 Mission 2   11 Orbcomm-OG2 satellites            2034.00
# 19                                              SES-9            5271.00
# 20                                       SpaceX CRS-8            3136.00
# 21                                           JCSAT-14            4696.00
# 22                                          Thaicom 8            3100.00
# 23                         ABS-2A Eutelsat 117 West B            3600.00
# 24                                       SpaceX CRS-9            2257.00
# 25                                           JCSAT-16            4600.00
# 26                                           CASSIOPE             500.00
# 27                                            Jason-3             553.00
# 28                                     Iridium NEXT 1            9600.00
# 29                                     Iridium NEXT 2            9600.00
# 30                                         Formosat-5             475.00
# 31                                     Iridium NEXT 3            9600.00
# 32                                     Iridium NEXT 4            9600.00
# 33                                  Paz  Tintin A & B            2150.00
# 34                                     Iridium NEXT 5            9600.00
# 35                     Iridium NEXT 6   GRACE-FO 1, 2            6460.00
# 36                                      SpaceX CRS-10            2490.00
# 37                                        EchoStar 23            5600.00
# 38                                             SES-10            5300.00
# 39                                            NROL-76            3696.65
# 40                                      Inmarsat-5 F4            6070.00
# 41                                      SpaceX CRS-11            2708.00
# 42                                      BulgariaSat-1            3669.00
# 43                                       Intelsat 35e            6761.00
# 44                                      SpaceX CRS-12            3310.00
# 45                                 Boeing X-37B OTV-5            4990.00
# 46                              SES-11 / EchoStar 105            5200.00
# 47                                        Koreasat 5A            3500.00
# 48                                      Bangabandhu-1            3600.00
# 49                                      SpaceX CRS-13            2205.00
# 50                                               Zuma            3696.65
# 51                                  GovSat-1 / SES-16            4230.00
# 52                             Hispasat 30W-6  PODSat            6092.00
# 53                                      SpaceX CRS-14            2647.00
# 54       Transiting Exoplanet Survey Satellite (TESS)             362.00
# 55                                             SES-12            5384.00
#
#            Orbit                            Customer  \
# 0            LEO                              SpaceX
# 1      LEO (ISS)                     NASA (COTS) NRO
# 2      LEO (ISS)                         NASA (COTS)
# 3      LEO (ISS)                          NASA (CRS)
# 4      LEO (ISS)                          NASA (CRS)
# 5            GTO                                 SES
# 6            GTO                             Thaicom
# 7      LEO (ISS)                          NASA (CRS)
# 8            LEO                             Orbcomm
# 9            GTO                             AsiaSat
# 10           GTO                             AsiaSat
# 11     LEO (ISS)                          NASA (CRS)
# 12     LEO (ISS)                          NASA (CRS)
# 13  Sun–Earth L1            U.S. Air Force NASA NOAA
# 14           GTO                        ABS Eutelsat
# 15     LEO (ISS)                          NASA (CRS)
# 16           GTO  Turkmenistan National Space Agency
# 17     LEO (ISS)                          NASA (CRS)
# 18           LEO                             Orbcomm
# 19           GTO                                 SES
# 20     LEO (ISS)                          NASA (CRS)
# 21           GTO              SKY Perfect JSAT Group
# 22           GTO                             Thaicom
# 23           GTO                        ABS Eutelsat
# 24     LEO (ISS)                          NASA (CRS)
# 25           GTO              SKY Perfect JSAT Group
# 26     Polar LEO                                 MDA
# 27           LEO                NASA (LSP) NOAA CNES
# 28     Polar LEO              Iridium Communications
# 29           LEO              Iridium Communications
# 30           SSO                                NSPO
# 31     Polar LEO              Iridium Communications
# 32     Polar LEO              Iridium Communications
# 33           SSO          Hisdesat exactEarth SpaceX
# 34     Polar LEO              Iridium Communications
# 35     Polar LEO   Iridium Communications GFZ • NASA
# 36     LEO (ISS)                          NASA (CRS)
# 37           GTO                            EchoStar
# 38           GTO                                 SES
# 39           LEO                                 NRO
# 40           GTO                            Inmarsat
# 41     LEO (ISS)                          NASA (CRS)
# 42           GTO                           Bulsatcom
# 43           GTO                            Intelsat
# 44     LEO (ISS)                          NASA (CRS)
# 45           LEO                      U.S. Air Force
# 46           GTO                        SES EchoStar
# 47           GTO                      KT Corporation
# 48           GTO                  Thales-Alenia/BTRC
# 49     LEO (ISS)                          NASA (CRS)
# 50           LEO                    Northrop Grumman
# 51           GTO                                 SES
# 52           GTO                 Hispasat  NovaWurks
# 53     LEO (ISS)                          NASA (CRS)
# 54           HEO                          NASA (LSP)
# 55           GTO                                 SES
#
#                       Mission Outcome          Landing Outcome  class  \
# 0                             Success    Failure   (parachute)      0
# 1                             Success    Failure   (parachute)      0
# 2                             Success               No attempt      0
# 3                             Success               No attempt      0
# 4                             Success               No attempt      0
# 5                             Success               No attempt      0
# 6                             Success               No attempt      0
# 7                             Success       Controlled (ocean)      0
# 8                             Success       Controlled (ocean)      0
# 9                             Success               No attempt      0
# 10                            Success               No attempt      0
# 11                            Success     Uncontrolled (ocean)      0
# 12                            Success    Failure  (drone ship)      0
# 13                            Success       Controlled (ocean)      0
# 14                            Success               No attempt      0
# 15                            Success    Failure  (drone ship)      0
# 16                            Success               No attempt      0
# 17               Failure  (in flight)  Precluded  (drone ship)      1
# 18                            Success    Success  (ground pad)      1
# 19                            Success     Failure (drone ship)      0
# 20                            Success    Success  (drone ship)      1
# 21                            Success     Success (drone ship)      1
# 22                            Success    Success  (drone ship)      1
# 23                            Success    Failure  (drone ship)      0
# 24                            Success     Success (ground pad)      1
# 25                            Success     Success (drone ship)      1
# 26                            Success     Uncontrolled (ocean)      0
# 27                            Success     Failure (drone ship)      0
# 28                            Success    Success  (drone ship)      1
# 29                            Success     Success (drone ship)      1
# 30                            Success     Success (drone ship)      1
# 31                            Success     Success (drone ship)      1
# 32                            Success       Controlled (ocean)      0
# 33                            Success               No attempt      0
# 34                            Success               No attempt      0
# 35                            Success               No attempt      0
# 36                            Success     Success (ground pad)      1
# 37                            Success               No attempt      0
# 38                            Success     Success (drone ship)      1
# 39                            Success     Success (ground pad)      1
# 40                            Success               No attempt      0
# 41                            Success     Success (ground pad)      1
# 42                            Success     Success (drone ship)      1
# 43                            Success               No attempt      0
# 44                            Success     Success (ground pad)      1
# 45                            Success     Success (ground pad)      1
# 46                            Success     Success (drone ship)      1
# 47                            Success     Success (drone ship)      1
# 48                            Success     Success (drone ship)      1
# 49                            Success     Success (ground pad)      1
# 50  Success  (payload status unclear)     Success (ground pad)      1
# 51                            Success       Controlled (ocean)      0
# 52                            Success               No attempt      0
# 53                            Success               No attempt      0
# 54                            Success     Success (drone ship)      1
# 55                            Success               No attempt      0
#
#           Lat        Long
# 0   28.562302  -80.577356
# 1   28.562302  -80.577356
# 2   28.562302  -80.577356
# 3   28.562302  -80.577356
# 4   28.562302  -80.577356
# 5   28.562302  -80.577356
# 6   28.562302  -80.577356
# 7   28.562302  -80.577356
# 8   28.562302  -80.577356
# 9   28.562302  -80.577356
# 10  28.562302  -80.577356
# 11  28.562302  -80.577356
# 12  28.562302  -80.577356
# 13  28.562302  -80.577356
# 14  28.562302  -80.577356
# 15  28.562302  -80.577356
# 16  28.562302  -80.577356
# 17  28.562302  -80.577356
# 18  28.562302  -80.577356
# 19  28.562302  -80.577356
# 20  28.562302  -80.577356
# 21  28.562302  -80.577356
# 22  28.562302  -80.577356
# 23  28.562302  -80.577356
# 24  28.562302  -80.577356
# 25  28.562302  -80.577356
# 26  34.632834 -120.610745
# 27  34.632834 -120.610745
# 28  34.632834 -120.610745
# 29  34.632834 -120.610745
# 30  34.632834 -120.610745
# 31  34.632834 -120.610745
# 32  34.632834 -120.610745
# 33  34.632834 -120.610745
# 34  34.632834 -120.610745
# 35  34.632834 -120.610745
# 36  28.573255  -80.646895
# 37  28.573255  -80.646895
# 38  28.573255  -80.646895
# 39  28.573255  -80.646895
# 40  28.573255  -80.646895
# 41  28.573255  -80.646895
# 42  28.573255  -80.646895
# 43  28.573255  -80.646895
# 44  28.573255  -80.646895
# 45  28.573255  -80.646895
# 46  28.573255  -80.646895
# 47  28.573255  -80.646895
# 48  28.573255  -80.646895
# 49  28.563197  -80.576820
# 50  28.563197  -80.576820
# 51  28.563197  -80.576820
# 52  28.563197  -80.576820
# 53  28.563197  -80.576820
# 54  28.563197  -80.576820
# 55  28.563197  -80.576820

# %%
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
# creating a folium Map object
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e96ee81178ab88ac4327e9a18dcac424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e96ee81178ab88ac4327e9a18dcac424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e96ee81178ab88ac4327e9a18dcac424 = L.map(
#                 &quot;map_e96ee81178ab88ac4327e9a18dcac424&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09a03b85666c0f005f064d645f18686b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#             var circle_1108491984fa9352e014c6a819ac99a7 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#         var popup_5e843272c2744c2c54cfb33758863582 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b2827ddf0ab4f5be3ff626d60f3368f = $(`&lt;div id=&quot;html_5b2827ddf0ab4f5be3ff626d60f3368f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_5e843272c2744c2c54cfb33758863582.setContent(html_5b2827ddf0ab4f5be3ff626d60f3368f);
#
#
#
#         circle_1108491984fa9352e014c6a819ac99a7.bindPopup(popup_5e843272c2744c2c54cfb33758863582)
#         ;
#
#
#
#
#             var marker_25ec9a5dbce23052aff8f709ce10abca = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#             var div_icon_d2c59d07cd4af335c76c324a25af4826 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_25ec9a5dbce23052aff8f709ce10abca.setIcon(div_icon_d2c59d07cd4af335c76c324a25af4826);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %%
marker_cluster = MarkerCluster()

# %%
# Function to assign color to launch outcome
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
spacex_df.tail(10)
# Out:
# C:\Users\MAHIKA\AppData\Local\Temp/ipykernel_3692/572784628.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
#      Launch Site        Lat       Long  class marker_color
# 46    KSC LC-39A  28.573255 -80.646895      1        green
# 47    KSC LC-39A  28.573255 -80.646895      1        green
# 48    KSC LC-39A  28.573255 -80.646895      1        green
# 49  CCAFS SLC-40  28.563197 -80.576820      1        green
# 50  CCAFS SLC-40  28.563197 -80.576820      1        green
# 51  CCAFS SLC-40  28.563197 -80.576820      0          red
# 52  CCAFS SLC-40  28.563197 -80.576820      0          red
# 53  CCAFS SLC-40  28.563197 -80.576820      0          red
# 54  CCAFS SLC-40  28.563197 -80.576820      1        green
# 55  CCAFS SLC-40  28.563197 -80.576820      0          red

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # Create and add a Marker cluster to the site map
    marker = folium.Marker([record['Lat'], record['Long']], 
                  icon=folium.Icon(color='white', icon_color=record['marker_color']))
    marker_cluster.add_child(marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e96ee81178ab88ac4327e9a18dcac424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e96ee81178ab88ac4327e9a18dcac424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e96ee81178ab88ac4327e9a18dcac424 = L.map(
#                 &quot;map_e96ee81178ab88ac4327e9a18dcac424&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09a03b85666c0f005f064d645f18686b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#             var circle_1108491984fa9352e014c6a819ac99a7 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#         var popup_5e843272c2744c2c54cfb33758863582 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b2827ddf0ab4f5be3ff626d60f3368f = $(`&lt;div id=&quot;html_5b2827ddf0ab4f5be3ff626d60f3368f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_5e843272c2744c2c54cfb33758863582.setContent(html_5b2827ddf0ab4f5be3ff626d60f3368f);
#
#
#
#         circle_1108491984fa9352e014c6a819ac99a7.bindPopup(popup_5e843272c2744c2c54cfb33758863582)
#         ;
#
#
#
#
#             var marker_25ec9a5dbce23052aff8f709ce10abca = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#             var div_icon_d2c59d07cd4af335c76c324a25af4826 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_25ec9a5dbce23052aff8f709ce10abca.setIcon(div_icon_d2c59d07cd4af335c76c324a25af4826);
#
#
#             var marker_cluster_78f80969598051713c4c988612f8af0d = L.markerClusterGroup(
#                 {}
#             );
#             map_e96ee81178ab88ac4327e9a18dcac424.addLayer(marker_cluster_78f80969598051713c4c988612f8af0d);
#
#
#             var marker_ae2d6e68668c2af7b03db4b15387ee6f = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_78f80969598051713c4c988612f8af0d);
#
#
#             var icon_4344d2ea50fe34b5614026d30b451521 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae2d6e68668c2af7b03db4b15387ee6f.setIcon(icon_4344d2ea50fe34b5614026d30b451521);
#
#
#             var marker_7b7335ec3a96a0d3216a9c163836b487 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_78f80969598051713c4c988612f8af0d);
#
#
#             var icon_c45c53a172c480abffa419fb296172fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7b7335ec3a96a0d3216a9c163836b487.setIcon(icon_c45c53a172c480abffa419fb296172fc);
#
#
#             var marker_b82e3fdf1fe1dbda5a8bf46746dc7ab9 = L.marker(
#                 [28.56230197, -80.57735648],

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e96ee81178ab88ac4327e9a18dcac424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e96ee81178ab88ac4327e9a18dcac424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e96ee81178ab88ac4327e9a18dcac424 = L.map(
#                 &quot;map_e96ee81178ab88ac4327e9a18dcac424&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09a03b85666c0f005f064d645f18686b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#             var circle_1108491984fa9352e014c6a819ac99a7 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#         var popup_5e843272c2744c2c54cfb33758863582 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b2827ddf0ab4f5be3ff626d60f3368f = $(`&lt;div id=&quot;html_5b2827ddf0ab4f5be3ff626d60f3368f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_5e843272c2744c2c54cfb33758863582.setContent(html_5b2827ddf0ab4f5be3ff626d60f3368f);
#
#
#
#         circle_1108491984fa9352e014c6a819ac99a7.bindPopup(popup_5e843272c2744c2c54cfb33758863582)
#         ;
#
#
#
#
#             var marker_25ec9a5dbce23052aff8f709ce10abca = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_e96ee81178ab88ac4327e9a18dcac424);
#
#
#             var div_icon_d2c59d07cd4af335c76c324a25af4826 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_25ec9a5dbce23052aff8f709ce10abca.setIcon(div_icon_d2c59d07cd4af335c76c324a25af4826);
#
#
#             var marker_cluster_78f80969598051713c4c988612f8af0d = L.markerClusterGroup(
#                 {}
#             );
#             map_e96ee81178ab88ac4327e9a18dcac424.addLayer(marker_cluster_78f80969598051713c4c988612f8af0d);
#
#
#             var marker_ae2d6e68668c2af7b03db4b15387ee6f = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_78f80969598051713c4c988612f8af0d);
#
#
#             var icon_4344d2ea50fe34b5614026d30b451521 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ae2d6e68668c2af7b03db4b15387ee6f.setIcon(icon_4344d2ea50fe34b5614026d30b451521);
#
#
#             var marker_7b7335ec3a96a0d3216a9c163836b487 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_78f80969598051713c4c988612f8af0d);
#
#
#             var icon_c45c53a172c480abffa419fb296172fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&q
